# %%
for p in ("Knet","ArgParse","Images","PlyIO")
    Pkg.installed(p) == nothing && Pkg.add(p)
end
using PlyIO
using Knet
using ArgParse
using Images

path = "scapecomp/"
##trial
data0 = load_ply("scapecomp/mesh000.ply")
#atype = gpu() >= 0 ? KnetArray{Float32} : Array{Float32}
datax = data0["vertex"]["x"]
datay = data0["vertex"]["y"]
dataz = data0["vertex"]["z"]
data1 = hcat(datax,datay)
data1 = hcat(data1,dataz)


files = readdir(path)
#println(files[1])
dataset=Any[]
for i in files
    data0 = load_ply(path * i)
    datax = data0["vertex"]["x"]
    datay = data0["vertex"]["y"]
    dataz = data0["vertex"]["z"]
    data1 = hcat(datax,datay)
    data1 = hcat(data1,dataz)
    data1 = reshape(data1,37500,1)
    dataset = push!(dataset,data1)
end

#println(size(dataset))
#dataset = minibatch(dataset, 1; xtype=atype)
#println(length(dataset))
#println(dataset)
##end of trial



const F = Float32

function encode(ϕ, x)
    x = mat(x)
    x = relu.(ϕ[1]*x .+ ϕ[2])
    μ = ϕ[3]*x .+ ϕ[4]
    logσ² = ϕ[5]*x .+ ϕ[6]
    return μ, logσ²
end

function decode(θ, z)
    z = relu.(θ[1]*z .+ θ[2])
    return sigm.(θ[3]*z .+ θ[4])
end

function binary_cross_entropy(x, x̂)
    s = @. x * log(x̂ + F(1e-10)) + (1-x) * log(1 - x̂ + F(1e-10))
    return -mean(s)
end

function output(w, x, nθ)
    θ, ϕ = w[1:nθ], w[nθ+1:end]
    μ, logσ² = encode(ϕ, x)
    nz, M = size(μ)
    σ² = exp.(logσ²)
    σ = sqrt.(σ²)

    #KL =  -sum(@. 1 + logσ² - μ*μ - σ²) / 2
    # Normalise by same number of elements as in reconstruction
    #KL /= M*28*28 ###1

    z = μ .+ randn!(similar(μ)) .* σ
    x̂ = decode(θ, z)
    #BCE = binary_cross_entropy(mat(x), x̂) ####2

    return x̂
end

function loss(w, x, nθ)
    θ, ϕ = w[1:nθ], w[nθ+1:end]
    μ, logσ² = encode(ϕ, x)
    nz, M = size(μ)
    σ² = exp.(logσ²)
    σ = sqrt.(σ²)

    KL =  -sum(@. 1 + logσ² - μ*μ - σ²) / 2
    # Normalise by same number of elements as in reconstruction
    KL /= M*28*28 ###1

    z = μ .+ randn!(similar(μ)) .* σ
    x̂ = decode(θ, z)
    BCE = mean(abs2,mat(x)-x̂)
    #BCE = binary_cross_entropy(mat(x), x̂) ####2

    return 1000*BCE #+ KL
end

function aveloss(θ, ϕ, data) #####3
    ls = F(0)
    nθ = length(θ)
    #for (x, y) in data
    for x in data
        ls += loss([θ; ϕ], x, nθ)
    end
    return ls / length(data)
end

function train!(θ, ϕ, data, opt; epochs=1)
    w = [θ; ϕ]
    for epoch=1:epochs
        for (x, y) in data
            dw = grad(loss)(w, x, length(θ))
            update!(w, dw, opt)
        end
    end
    return θ, ϕ
end

function weights(nz, nh; atype=Array{F})
    θ = [  # z->x
        xavier(nh, nz),
        zeros(nh),
        xavier(12500*3, nh), #x
        zeros(12500*3)
        ]
    θ = map(a->convert(atype,a), θ)

    ϕ = [ # x->z
        xavier(nh, 12500*3),
        zeros(nh),
        xavier(nz, nh), #μ
        zeros(nz),
        xavier(nz, nh), #σ
        zeros(nz)
        ]
    ϕ = map(a->convert(atype,a), ϕ)

    return θ, ϕ
end

function main(args="")
    s = ArgParseSettings()
    s.description="Variational Auto Encoder on MNIST dataset."
    s.exc_handler=ArgParse.debug_handler
    @add_arg_table s begin
        ("--seed"; arg_type=Int; default=-1; help="random number seed: use a nonnegative int for repeatable results")
        ("--batchsize"; arg_type=Int; default=100; help="minibatch size")
        ("--epochs"; arg_type=Int; default=10; help="number of epochs for training")
        ("--nh"; arg_type=Int; default=400; help="hidden layer dimension")
        ("--nz"; arg_type=Int; default=40; help="encoding dimention")
        ("--lr"; arg_type=Float64; default=1e-2; help="learning rate")
        ("--atype"; default=(gpu()>=0 ? "KnetArray{F}" : "Array{F}"); help="array type: Array for cpu, KnetArray for gpu")
        ("--infotime"; arg_type=Int; default=2; help="report every infotime epochs")
    end
    isa(args, String) && (args=split(args))
    if in("--help", args) || in("-h", args)
        ArgParse.show_help(s; exit_when_done=false)
        return
    end
    o = parse_args(args, s; as_symbols=true)

    atype = eval(parse(o[:atype]))
    info("using ", atype)
    o[:seed] > 0 && setseed(o[:seed])

    θ, ϕ = weights(o[:nz], o[:nh], atype=atype)
    w = [θ; ϕ]
    opt = optimizers(w, Adam, lr=o[:lr])

    path = "scapecomp/"
    files = readdir(path)
    dataset=Any[]
    for i in files
        data0 = load_ply(path * i)
        datax = data0["vertex"]["x"]
        datay = data0["vertex"]["y"]
        dataz = data0["vertex"]["z"]
        data1 = hcat(datax,datay)
        data1 = hcat(data1,dataz)
        data1=data1/2
        data1[:,2]=data1[:,2]+0.5
        data1[:,3]=data1[:,3]+0.5 
        data1 = reshape(data1,37500,1)
        dataset = push!(dataset,atype(data1))
    end
    #println(typeof(dataset))
    #println(size(dataset))
    #dataset = reshape(dataset,12500,3,1,72)
    #println(size(dataset))
    #dataset = minibatch(dataset,1;xtype=atype())

    #for (d1,d2) in dataset
    #    println(d1)
    #    break
    #end
    #println(size(dataset[1]))
    randomout = output(w, atype(reshape(dataset[1],37500,1)), length(θ))
    #return reshape(randomout,12500,3)

    #####TRAINING PART#######
    report(epoch) = begin
            #dtrn = minibatch(xtrn, ytrn, o[:batchsize]; xtype=atype)
            #dtst = minibatch(xtst, ytst, o[:batchsize]; xtype=atype)
            println((:epoch, epoch,
                     :trn, aveloss(θ, ϕ, dataset),
                     :length, length(dataset)))
    end

    report(0); tic()
    @time for epoch=1:o[:epochs]
        for x in dataset
            #println(loss(w, atype(reshape(x,37500,1)), length(θ)))           
            dw = grad(loss)(w, atype(reshape(x,37500,1)), length(θ))
            #println(dw[1][1])
            update!(w, dw, opt)
        end
        (epoch % o[:infotime] == 0) && (report(epoch); toc(); tic())
        #println(23)
    end; toq()
    samplein = dataset[1]
    sampleout = output(w, atype(reshape(dataset[1],37500,1)), length(θ))
    sampleout = reshape(sampleout,12500,3)
    return θ, ϕ, reshape(randomout,12500,3), w, sampleout, samplein

end

#return randomout

#end # module

p1, p2, randomout, w, sampleout, samplein = main("--infotime 1 --seed 1 --epochs 300");
println(size(randomout))
sampleout=Array{Float64,2}(sampleout)
writedlm("test5.xyz", sampleout)
#println(randomout)
# Out:
# INFO: using Knet.KnetArray{Float32,N} where N
# (:epoch, 0, :trn, 27.27968f0, :length, 26)
# (:epoch, 1, :trn, 20.34414f0, :length, 26)
# elapsed time: 4.19915355 seconds
# (:epoch, 2, :trn, 15.966425f0, :length, 26)
# elapsed time: 0.964608867 seconds
# (:epoch, 3, :trn, 13.3533325f0, :length, 26)
# elapsed time: 0.95219547 seconds
# (:epoch, 4, :trn, 11.775665f0, :length, 26)
# elapsed time: 1.08767913 seconds
# (:epoch, 5, :trn, 10.794313f0, :length, 26)
# elapsed time: 0.957412926 seconds
# (:epoch, 6, :trn, 10.161933f0, :length, 26)
# elapsed time: 0.960526598 seconds
# (:epoch, 7, :trn, 9.739662f0, :length, 26)
# elapsed time: 0.977113803 seconds
# (:epoch, 8, :trn, 9.448096f0, :length, 26)
# elapsed time: 1.10973209 seconds
# (:epoch, 9, :trn, 9.240554f0, :length, 26)
# elapsed time: 0.990130358 seconds
# (:epoch, 10, :trn, 9.088732f0, :length, 26)
# elapsed time: 0.9589254 seconds
# (:epoch, 11, :trn, 8.974946f0, :length, 26)
# elapsed time: 1.089314463 seconds
# (:epoch, 12, :trn, 8.887813f0, :length, 26)
# elapsed time: 0.96330066 seconds
# (:epoch, 13, :trn, 8.819811f0, :length, 26)
# elapsed time: 0.952352642 seconds
# (:epoch, 14, :trn, 8.765838f0, :length, 26)
# elapsed time: 0.954799793 seconds
# (:epoch, 15, :trn, 8.722356f0, :length, 26)
# elapsed time: 1.090452089 seconds
# (:epoch, 16, :trn, 8.686861f0, :length, 26)
# elapsed time: 0.97470939 seconds
# (:epoch, 17, :trn, 8.657543f0, :length, 26)
# elapsed time: 0.95806022 seconds
# (:epoch, 18, :trn, 8.633074f0, :length, 26)
# elapsed time: 1.09530194 seconds
# (:epoch, 19, :trn, 8.612457f0, :length, 26)
# elapsed time: 0.958829325 seconds
# (:epoch, 20, :trn, 8.594939f0, :length, 26)
# elapsed time: 0.959615825 seconds
# (:epoch, 21, :trn, 8.579945f0, :length, 26)
# elapsed time: 0.961223556 seconds
# (:epoch, 22, :trn, 8.5670185f0, :length, 26)
# elapsed time: 1.086198347 seconds
# (:epoch, 23, :trn, 8.555806f0, :length, 26)
# elapsed time: 0.956683152 seconds
# (:epoch, 24, :trn, 8.546026f0, :length, 26)
# elapsed time: 0.960827034 seconds
# (:epoch, 25, :trn, 8.537449f0, :length, 26)
# elapsed time: 1.0882756 seconds
# (:epoch, 26, :trn, 8.529894f0, :length, 26)
# elapsed time: 0.956203001 seconds
# (:epoch, 27, :trn, 8.523207f0, :length, 26)
# elapsed time: 0.952415442 seconds
# (:epoch, 28, :trn, 8.517265f0, :length, 26)
# elapsed time: 0.954179609 seconds
# (:epoch, 29, :trn, 8.511967f0, :length, 26)
# elapsed time: 1.08706926 seconds
# (:epoch, 30, :trn, 8.507223f0, :length, 26)
# elapsed time: 0.966609834 seconds
# (:epoch, 31, :trn, 8.502964f0, :length, 26)
# elapsed time: 0.957504946 seconds
# (:epoch, 32, :trn, 8.499126f0, :length, 26)
# elapsed time: 1.087238598 seconds
# (:epoch, 33, :trn, 8.495659f0, :length, 26)
# elapsed time: 0.959188288 seconds
# (:epoch, 34, :trn, 8.492519f0, :length, 26)
# elapsed time: 0.955537263 seconds
# (:epoch, 35, :trn, 8.489666f0, :length, 26)
# elapsed time: 0.958083919 seconds
# (:epoch, 36, :trn, 8.48707f0, :length, 26)
# elapsed time: 1.086579329 seconds
# (:epoch, 37, :trn, 8.484701f0, :length, 26)
# elapsed time: 0.956585913 seconds
# (:epoch, 38, :trn, 8.482535f0, :length, 26)
# elapsed time: 0.955196591 seconds
# (:epoch, 39, :trn, 8.48055f0, :length, 26)
# elapsed time: 1.086907247 seconds
# (:epoch, 40, :trn, 8.478728f0, :length, 26)
# elapsed time: 0.96541505 seconds
# (:epoch, 41, :trn, 8.477051f0, :length, 26)
# elapsed time: 0.95404052 seconds
# (:epoch, 42, :trn, 8.475509f0, :length, 26)
# elapsed time: 0.95897877 seconds
# (:epoch, 43, :trn, 8.474081f0, :length, 26)
# elapsed time: 1.088686386 seconds
# (:epoch, 44, :trn, 8.472765f0, :length, 26)
# elapsed time: 0.961257196 seconds
# (:epoch, 45, :trn, 8.471544f0, :length, 26)
# elapsed time: 0.951411498 seconds
# (:epoch, 46, :trn, 8.470415f0, :length, 26)
# elapsed time: 1.088613895 seconds
# (:epoch, 47, :trn, 8.469363f0, :length, 26)
# elapsed time: 0.955213255 seconds
# (:epoch, 48, :trn, 8.468388f0, :length, 26)
# elapsed time: 0.952728648 seconds
# (:epoch, 49, :trn, 8.46748f0, :length, 26)
# elapsed time: 0.964816228 seconds
# (:epoch, 50, :trn, 8.466632f0, :length, 26)
# elapsed time: 1.090455368 seconds
# (:epoch, 51, :trn, 8.465841f0, :length, 26)
# elapsed time: 0.959227819 seconds
# (:epoch, 52, :trn, 8.465104f0, :length, 26)
# elapsed time: 0.959143902 seconds
# (:epoch, 53, :trn, 8.464416f0, :length, 26)
# elapsed time: 1.092156311 seconds
# (:epoch, 54, :trn, 8.463767f0, :length, 26)
# elapsed time: 0.957830352 seconds
# (:epoch, 55, :trn, 8.463163f0, :length, 26)
# elapsed time: 0.959634379 seconds
# (:epoch, 56, :trn, 8.462597f0, :length, 26)
# elapsed time: 0.958217732 seconds
# (:epoch, 57, :trn, 8.462062f0, :length, 26)
# elapsed time: 1.086393789 seconds
# (:epoch, 58, :trn, 8.461561f0, :length, 26)
# elapsed time: 0.956733856 seconds
# (:epoch, 59, :trn, 8.46109f0, :length, 26)
# elapsed time: 0.955005893 seconds
# (:epoch, 60, :trn, 8.460647f0, :length, 26)
# elapsed time: 1.09096168 seconds
# (:epoch, 61, :trn, 8.460228f0, :length, 26)
# elapsed time: 0.968483059 seconds
# (:epoch, 62, :trn, 8.459834f0, :length, 26)
# elapsed time: 0.952043144 seconds
# (:epoch, 63, :trn, 8.459463f0, :length, 26)
# elapsed time: 0.958445718 seconds
# (:epoch, 64, :trn, 8.459112f0, :length, 26)
# elapsed time: 1.084240994 seconds
# (:epoch, 65, :trn, 8.458779f0, :length, 26)
# elapsed time: 0.955029705 seconds
# (:epoch, 66, :trn, 8.458467f0, :length, 26)
# elapsed time: 0.958368325 seconds
# (:epoch, 67, :trn, 8.458168f0, :length, 26)
# elapsed time: 1.09286515 seconds
# (:epoch, 68, :trn, 8.457888f0, :length, 26)
# elapsed time: 0.95629084 seconds
# (:epoch, 69, :trn, 8.457621f0, :length, 26)
# elapsed time: 0.951539221 seconds
# (:epoch, 70, :trn, 8.457368f0, :length, 26)
# elapsed time: 0.954960034 seconds
# (:epoch, 71, :trn, 8.4571295f0, :length, 26)
# elapsed time: 1.084945453 seconds
# (:epoch, 72, :trn, 8.456902f0, :length, 26)
# elapsed time: 0.9541731 seconds
# (:epoch, 73, :trn, 8.456685f0, :length, 26)
# elapsed time: 0.958266122 seconds
# (:epoch, 74, :trn, 8.45648f0, :length, 26)
# elapsed time: 1.091917514 seconds
# (:epoch, 75, :trn, 8.456285f0, :length, 26)
# elapsed time: 0.959857802 seconds
# (:epoch, 76, :trn, 8.4560995f0, :length, 26)
# elapsed time: 0.989258492 seconds
# (:epoch, 77, :trn, 8.455924f0, :length, 26)
# elapsed time: 0.956522408 seconds
# (:epoch, 78, :trn, 8.455755f0, :length, 26)
# elapsed time: 1.087218709 seconds
# (:epoch, 79, :trn, 8.455595f0, :length, 26)
# elapsed time: 0.968139174 seconds
# (:epoch, 80, :trn, 8.455441f0, :length, 26)
# elapsed time: 0.965988179 seconds
# (:epoch, 81, :trn, 8.455296f0, :length, 26)
# elapsed time: 1.11608783 seconds
# (:epoch, 82, :trn, 8.455158f0, :length, 26)
# elapsed time: 0.970564943 seconds
# (:epoch, 83, :trn, 8.455024f0, :length, 26)
# elapsed time: 0.990203954 seconds
# (:epoch, 84, :trn, 8.454897f0, :length, 26)
# elapsed time: 0.973326934 seconds
# (:epoch, 85, :trn, 8.454777f0, :length, 26)
# elapsed time: 1.094335479 seconds
# (:epoch, 86, :trn, 8.45466f0, :length, 26)
# elapsed time: 0.964842645 seconds
# (:epoch, 87, :trn, 8.454551f0, :length, 26)
# elapsed time: 0.957834485 seconds
# (:epoch, 88, :trn, 8.454445f0, :length, 26)
# elapsed time: 1.092091587 seconds
# (:epoch, 89, :trn, 8.454344f0, :length, 26)
# elapsed time: 0.958473248 seconds
# (:epoch, 90, :trn, 8.454246f0, :length, 26)
# elapsed time: 0.958571873 seconds
# (:epoch, 91, :trn, 8.454154f0, :length, 26)
# elapsed time: 0.961023293 seconds
# (:epoch, 92, :trn, 8.454065f0, :length, 26)
# elapsed time: 1.100011309 seconds
# (:epoch, 93, :trn, 8.4539795f0, :length, 26)
# elapsed time: 0.963435978 seconds
# (:epoch, 94, :trn, 8.453899f0, :length, 26)
# elapsed time: 0.956242065 seconds
# (:epoch, 95, :trn, 8.453819f0, :length, 26)
# elapsed time: 1.094979746 seconds
# (:epoch, 96, :trn, 8.453744f0, :length, 26)
# elapsed time: 0.960276524 seconds
# (:epoch, 97, :trn, 8.453672f0, :length, 26)
# elapsed time: 0.954632494 seconds
# (:epoch, 98, :trn, 8.453603f0, :length, 26)
# elapsed time: 0.96293183 seconds
# (:epoch, 99, :trn, 8.453537f0, :length, 26)
# elapsed time: 1.092831827 seconds
# (:epoch, 100, :trn, 8.453472f0, :length, 26)
# elapsed time: 0.957295279 seconds
# (:epoch, 101, :trn, 8.453412f0, :length, 26)
# elapsed time: 0.955686569 seconds
# (:epoch, 102, :trn, 8.453353f0, :length, 26)
# elapsed time: 1.089339767 seconds
# (:epoch, 103, :trn, 8.453297f0, :length, 26)
# elapsed time: 0.954857087 seconds
# (:epoch, 104, :trn, 8.45324f0, :length, 26)
# elapsed time: 0.954062307 seconds
# (:epoch, 105, :trn, 8.453189f0, :length, 26)
# elapsed time: 0.962032543 seconds
# (:epoch, 106, :trn, 8.453139f0, :length, 26)
# elapsed time: 1.089218389 seconds
# (:epoch, 107, :trn, 8.453091f0, :length, 26)
# elapsed time: 0.96059415 seconds
# (:epoch, 108, :trn, 8.453042f0, :length, 26)
# elapsed time: 0.954866305 seconds
# (:epoch, 109, :trn, 8.452997f0, :length, 26)
# elapsed time: 1.089276857 seconds
# (:epoch, 110, :trn, 8.452955f0, :length, 26)
# elapsed time: 0.96218813 seconds
# (:epoch, 111, :trn, 8.452912f0, :length, 26)
# elapsed time: 0.957551936 seconds
# (:epoch, 112, :trn, 8.452872f0, :length, 26)
# elapsed time: 0.95792441 seconds
# (:epoch, 113, :trn, 8.452833f0, :length, 26)
# elapsed time: 1.089160532 seconds
# (:epoch, 114, :trn, 8.452796f0, :length, 26)
# elapsed time: 0.957705707 seconds
# (:epoch, 115, :trn, 8.45276f0, :length, 26)
# elapsed time: 0.952788721 seconds
# (:epoch, 116, :trn, 8.452726f0, :length, 26)
# elapsed time: 1.091939222 seconds
# (:epoch, 117, :trn, 8.452692f0, :length, 26)
# elapsed time: 0.961202853 seconds
# (:epoch, 118, :trn, 8.452659f0, :length, 26)
# elapsed time: 0.950812802 seconds
# (:epoch, 119, :trn, 8.452627f0, :length, 26)
# elapsed time: 0.953968223 seconds
# (:epoch, 120, :trn, 8.452597f0, :length, 26)
# elapsed time: 1.08121183 seconds
# (:epoch, 121, :trn, 8.452567f0, :length, 26)
# elapsed time: 0.955489696 seconds
# (:epoch, 122, :trn, 8.452539f0, :length, 26)
# elapsed time: 0.952904041 seconds
# (:epoch, 123, :trn, 8.452513f0, :length, 26)
# elapsed time: 1.090915221 seconds
# (:epoch, 124, :trn, 8.452486f0, :length, 26)
# elapsed time: 0.959680631 seconds
# (:epoch, 125, :trn, 8.452461f0, :length, 26)
# elapsed time: 0.958889753 seconds
# (:epoch, 126, :trn, 8.452436f0, :length, 26)
# elapsed time: 0.963747183 seconds
# (:epoch, 127, :trn, 8.452414f0, :length, 26)
# elapsed time: 1.089672414 seconds
# (:epoch, 128, :trn, 8.452389f0, :length, 26)
# elapsed time: 0.959382474 seconds
# (:epoch, 129, :trn, 8.452367f0, :length, 26)
# elapsed time: 0.953999917 seconds
# (:epoch, 130, :trn, 8.452345f0, :length, 26)
# elapsed time: 1.092486271 seconds
# (:epoch, 131, :trn, 8.452325f0, :length, 26)
# elapsed time: 0.960221136 seconds
# (:epoch, 132, :trn, 8.452303f0, :length, 26)
# elapsed time: 0.953118812 seconds
# (:epoch, 133, :trn, 8.452285f0, :length, 26)
# elapsed time: 0.960866588 seconds
# (:epoch, 134, :trn, 8.452267f0, :length, 26)
# elapsed time: 1.089261958 seconds
# (:epoch, 135, :trn, 8.452248f0, :length, 26)
# elapsed time: 0.96497084 seconds
# (:epoch, 136, :trn, 8.4522295f0, :length, 26)
# elapsed time: 0.970598362 seconds
# (:epoch, 137, :trn, 8.452211f0, :length, 26)
# elapsed time: 1.117592036 seconds
# (:epoch, 138, :trn, 8.452196f0, :length, 26)
# elapsed time: 0.977832112 seconds
# (:epoch, 139, :trn, 8.452178f0, :length, 26)
# elapsed time: 0.967272239 seconds
# (:epoch, 140, :trn, 8.452163f0, :length, 26)
# elapsed time: 0.961677205 seconds
# (:epoch, 141, :trn, 8.452148f0, :length, 26)
# elapsed time: 1.097853438 seconds
# (:epoch, 142, :trn, 8.452132f0, :length, 26)
# elapsed time: 0.969413849 seconds
# (:epoch, 143, :trn, 8.452118f0, :length, 26)
# elapsed time: 0.962172523 seconds
# (:epoch, 144, :trn, 8.452105f0, :length, 26)
# elapsed time: 1.091463491 seconds
# (:epoch, 145, :trn, 8.452093f0, :length, 26)
# elapsed time: 0.956290562 seconds
# (:epoch, 146, :trn, 8.452079f0, :length, 26)
# elapsed time: 0.961423087 seconds
# (:epoch, 147, :trn, 8.452065f0, :length, 26)
# elapsed time: 0.963532371 seconds
# (:epoch, 148, :trn, 8.452054f0, :length, 26)
# elapsed time: 1.0897709 seconds
# (:epoch, 149, :trn, 8.452042f0, :length, 26)
# elapsed time: 0.957698524 seconds
# (:epoch, 150, :trn, 8.45203f0, :length, 26)
# elapsed time: 0.955123753 seconds
# (:epoch, 151, :trn, 8.452019f0, :length, 26)
# elapsed time: 1.09451689 seconds
# (:epoch, 152, :trn, 8.452008f0, :length, 26)
# elapsed time: 0.955492673 seconds
# (:epoch, 153, :trn, 8.451997f0, :length, 26)
# elapsed time: 0.954265506 seconds
# (:epoch, 154, :trn, 8.451987f0, :length, 26)
# elapsed time: 0.964792318 seconds
# (:epoch, 155, :trn, 8.451977f0, :length, 26)
# elapsed time: 1.092111831 seconds
# (:epoch, 156, :trn, 8.451968f0, :length, 26)
# elapsed time: 0.962329836 seconds
# (:epoch, 157, :trn, 8.451958f0, :length, 26)
# elapsed time: 0.958393095 seconds
# (:epoch, 158, :trn, 8.451949f0, :length, 26)
# elapsed time: 1.094579679 seconds
# (:epoch, 159, :trn, 8.45194f0, :length, 26)
# elapsed time: 0.965247279 seconds
# (:epoch, 160, :trn, 8.45193f0, :length, 26)
# elapsed time: 0.965791719 seconds
# (:epoch, 161, :trn, 8.451922f0, :length, 26)
# elapsed time: 0.974303779 seconds
# (:epoch, 162, :trn, 8.451915f0, :length, 26)
# elapsed time: 1.08883486 seconds
# (:epoch, 163, :trn, 8.451906f0, :length, 26)
# elapsed time: 0.964477979 seconds
# (:epoch, 164, :trn, 8.4519f0, :length, 26)
# elapsed time: 0.956064729 seconds
# (:epoch, 165, :trn, 8.451891f0, :length, 26)
# elapsed time: 1.090246603 seconds
# (:epoch, 166, :trn, 8.451883f0, :length, 26)
# elapsed time: 0.966088549 seconds
# (:epoch, 167, :trn, 8.451876f0, :length, 26)
# elapsed time: 0.969458557 seconds
# (:epoch, 168, :trn, 8.451869f0, :length, 26)
# elapsed time: 0.967226382 seconds
# (:epoch, 169, :trn, 8.451863f0, :length, 26)
# elapsed time: 1.102103476 seconds
# (:epoch, 170, :trn, 8.451857f0, :length, 26)
# elapsed time: 0.966671354 seconds
# (:epoch, 171, :trn, 8.451849f0, :length, 26)
# elapsed time: 0.959399318 seconds
# (:epoch, 172, :trn, 8.451844f0, :length, 26)
# elapsed time: 1.092540225 seconds
# (:epoch, 173, :trn, 8.451837f0, :length, 26)
# elapsed time: 0.964559082 seconds
# (:epoch, 174, :trn, 8.451831f0, :length, 26)
# elapsed time: 0.9555058 seconds
# (:epoch, 175, :trn, 8.451825f0, :length, 26)
# elapsed time: 0.968066891 seconds
# (:epoch, 176, :trn, 8.45182f0, :length, 26)
# elapsed time: 1.101219044 seconds
# (:epoch, 177, :trn, 8.451815f0, :length, 26)
# elapsed time: 0.969400013 seconds
# (:epoch, 178, :trn, 8.45181f0, :length, 26)
# elapsed time: 0.963644728 seconds
# (:epoch, 179, :trn, 8.451803f0, :length, 26)
# elapsed time: 1.109026681 seconds
# (:epoch, 180, :trn, 8.451798f0, :length, 26)
# elapsed time: 0.96568485 seconds
# (:epoch, 181, :trn, 8.451794f0, :length, 26)
# elapsed time: 0.955172341 seconds
# (:epoch, 182, :trn, 8.451789f0, :length, 26)
# elapsed time: 0.957537088 seconds
# (:epoch, 183, :trn, 8.451784f0, :length, 26)
# elapsed time: 1.085585167 seconds
# (:epoch, 184, :trn, 8.451779f0, :length, 26)
# elapsed time: 0.961855793 seconds
# (:epoch, 185, :trn, 8.451775f0, :length, 26)
# elapsed time: 0.962029684 seconds
# (:epoch, 186, :trn, 8.451771f0, :length, 26)
# elapsed time: 1.102591843 seconds
# (:epoch, 187, :trn, 8.451766f0, :length, 26)
# elapsed time: 0.961927943 seconds
# (:epoch, 188, :trn, 8.451761f0, :length, 26)
# elapsed time: 0.962861014 seconds
# (:epoch, 189, :trn, 8.451757f0, :length, 26)
# elapsed time: 0.966261258 seconds
# (:epoch, 190, :trn, 8.451755f0, :length, 26)
# elapsed time: 1.100540552 seconds
# (:epoch, 191, :trn, 8.451751f0, :length, 26)
# elapsed time: 0.972888685 seconds
# (:epoch, 192, :trn, 8.451746f0, :length, 26)
# elapsed time: 0.966237111 seconds
# (:epoch, 193, :trn, 8.451742f0, :length, 26)
# elapsed time: 1.100945609 seconds
# (:epoch, 194, :trn, 8.451738f0, :length, 26)
# elapsed time: 0.967001593 seconds
# (:epoch, 195, :trn, 8.4517355f0, :length, 26)
# elapsed time: 0.969655627 seconds
# (:epoch, 196, :trn, 8.451735f0, :length, 26)
# elapsed time: 0.973682788 seconds
# (:epoch, 197, :trn, 8.45173f0, :length, 26)
# elapsed time: 1.110980307 seconds
# (:epoch, 198, :trn, 8.451726f0, :length, 26)
# elapsed time: 0.962923696 seconds
# (:epoch, 199, :trn, 8.451723f0, :length, 26)
# elapsed time: 0.956965188 seconds
# (:epoch, 200, :trn, 8.451719f0, :length, 26)
# elapsed time: 1.105114006 seconds
# (:epoch, 201, :trn, 8.451717f0, :length, 26)
# elapsed time: 0.960198347 seconds
# (:epoch, 202, :trn, 8.4517145f0, :length, 26)
# elapsed time: 0.956753072 seconds
# (:epoch, 203, :trn, 8.451711f0, :length, 26)
# elapsed time: 0.965836818 seconds
# (:epoch, 204, :trn, 8.451708f0, :length, 26)
# elapsed time: 1.098098183 seconds
# (:epoch, 205, :trn, 8.451705f0, :length, 26)
# elapsed time: 0.963028267 seconds
# (:epoch, 206, :trn, 8.451703f0, :length, 26)
# elapsed time: 0.960610647 seconds
# (:epoch, 207, :trn, 8.4517f0, :length, 26)
# elapsed time: 1.101717012 seconds
# (:epoch, 208, :trn, 8.451697f0, :length, 26)
# elapsed time: 0.967555492 seconds
# (:epoch, 209, :trn, 8.4516945f0, :length, 26)
# elapsed time: 0.965027193 seconds
# (:epoch, 210, :trn, 8.4516945f0, :length, 26)
# elapsed time: 0.982174897 seconds
# (:epoch, 211, :trn, 8.45169f0, :length, 26)
# elapsed time: 1.103866611 seconds
# (:epoch, 212, :trn, 8.451688f0, :length, 26)
# elapsed time: 0.969545604 seconds
# (:epoch, 213, :trn, 8.451686f0, :length, 26)
# elapsed time: 0.963065183 seconds
# (:epoch, 214, :trn, 8.451685f0, :length, 26)
# elapsed time: 1.110473939 seconds
# (:epoch, 215, :trn, 8.451682f0, :length, 26)
# elapsed time: 0.97240201 seconds
# (:epoch, 216, :trn, 8.451679f0, :length, 26)
# elapsed time: 0.970310743 seconds
# (:epoch, 217, :trn, 8.451677f0, :length, 26)
# elapsed time: 0.98741735 seconds
# (:epoch, 218, :trn, 8.451676f0, :length, 26)
# elapsed time: 1.123264728 seconds
# (:epoch, 219, :trn, 8.4516735f0, :length, 26)
# elapsed time: 0.988469448 seconds
# (:epoch, 220, :trn, 8.451672f0, :length, 26)
# elapsed time: 0.969815218 seconds
# (:epoch, 221, :trn, 8.45167f0, :length, 26)
# elapsed time: 1.105976505 seconds
# (:epoch, 222, :trn, 8.451668f0, :length, 26)
# elapsed time: 0.975420577 seconds
# (:epoch, 223, :trn, 8.451666f0, :length, 26)
# elapsed time: 0.970337203 seconds
# (:epoch, 224, :trn, 8.451664f0, :length, 26)
# elapsed time: 0.973338587 seconds
# (:epoch, 225, :trn, 8.451664f0, :length, 26)
# elapsed time: 1.110292736 seconds
# (:epoch, 226, :trn, 8.451661f0, :length, 26)
# elapsed time: 0.976522172 seconds
# (:epoch, 227, :trn, 8.451659f0, :length, 26)
# elapsed time: 0.97278208 seconds
# (:epoch, 228, :trn, 8.451656f0, :length, 26)
# elapsed time: 1.114601708 seconds
# (:epoch, 229, :trn, 8.451657f0, :length, 26)
# elapsed time: 0.970826142 seconds
# (:epoch, 230, :trn, 8.451654f0, :length, 26)
# elapsed time: 0.967347803 seconds
# (:epoch, 231, :trn, 8.4516535f0, :length, 26)
# elapsed time: 0.97631491 seconds
# (:epoch, 232, :trn, 8.4516535f0, :length, 26)
# elapsed time: 1.109134408 seconds
# (:epoch, 233, :trn, 8.451651f0, :length, 26)
# elapsed time: 0.969356348 seconds
# (:epoch, 234, :trn, 8.451649f0, :length, 26)
# elapsed time: 0.967253893 seconds
# (:epoch, 235, :trn, 8.451647f0, :length, 26)
# elapsed time: 1.107043751 seconds
# (:epoch, 236, :trn, 8.451647f0, :length, 26)
# elapsed time: 0.967862231 seconds
# (:epoch, 237, :trn, 8.451646f0, :length, 26)
# elapsed time: 0.959685208 seconds
# (:epoch, 238, :trn, 8.451644f0, :length, 26)
# elapsed time: 0.980676124 seconds
# (:epoch, 239, :trn, 8.451642f0, :length, 26)
# elapsed time: 1.117936597 seconds
# (:epoch, 240, :trn, 8.451641f0, :length, 26)
# elapsed time: 0.97325148 seconds
# (:epoch, 241, :trn, 8.451639f0, :length, 26)
# elapsed time: 0.956717498 seconds
# (:epoch, 242, :trn, 8.451639f0, :length, 26)
# elapsed time: 1.089955094 seconds
# (:epoch, 243, :trn, 8.451638f0, :length, 26)
# elapsed time: 0.962840229 seconds
# (:epoch, 244, :trn, 8.451636f0, :length, 26)
# elapsed time: 0.959581318 seconds
# (:epoch, 245, :trn, 8.451636f0, :length, 26)
# elapsed time: 0.962357475 seconds
# (:epoch, 246, :trn, 8.451635f0, :length, 26)
# elapsed time: 1.094613167 seconds
# (:epoch, 247, :trn, 8.451633f0, :length, 26)
# elapsed time: 0.957120226 seconds
# (:epoch, 248, :trn, 8.4516325f0, :length, 26)
# elapsed time: 0.955766502 seconds
# (:epoch, 249, :trn, 8.451632f0, :length, 26)
# elapsed time: 1.09592173 seconds
# (:epoch, 250, :trn, 8.451631f0, :length, 26)
# elapsed time: 0.968279 seconds
# (:epoch, 251, :trn, 8.451629f0, :length, 26)
# elapsed time: 0.96405199 seconds
# (:epoch, 252, :trn, 8.451629f0, :length, 26)
# elapsed time: 0.968332518 seconds
# (:epoch, 253, :trn, 8.451628f0, :length, 26)
# elapsed time: 1.113126888 seconds
# (:epoch, 254, :trn, 8.451629f0, :length, 26)
# elapsed time: 0.975612852 seconds
# (:epoch, 255, :trn, 8.451627f0, :length, 26)
# elapsed time: 0.968765916 seconds
# (:epoch, 256, :trn, 8.451625f0, :length, 26)
# elapsed time: 1.117281532 seconds
# (:epoch, 257, :trn, 8.451624f0, :length, 26)
# elapsed time: 0.974769412 seconds
# (:epoch, 258, :trn, 8.451623f0, :length, 26)
# elapsed time: 0.973279787 seconds
# (:epoch, 259, :trn, 8.451623f0, :length, 26)
# elapsed time: 0.978244674 seconds
# (:epoch, 260, :trn, 8.451623f0, :length, 26)
# elapsed time: 1.111455573 seconds
# (:epoch, 261, :trn, 8.451621f0, :length, 26)
# elapsed time: 0.971635428 seconds
# (:epoch, 262, :trn, 8.451621f0, :length, 26)
# elapsed time: 0.975496216 seconds
# (:epoch, 263, :trn, 8.45162f0, :length, 26)
# elapsed time: 1.112706537 seconds
# (:epoch, 264, :trn, 8.451618f0, :length, 26)
# elapsed time: 0.973046089 seconds
# (:epoch, 265, :trn, 8.451618f0, :length, 26)
# elapsed time: 0.973176765 seconds
# (:epoch, 266, :trn, 8.451617f0, :length, 26)
# elapsed time: 0.975978414 seconds
# (:epoch, 267, :trn, 8.451616f0, :length, 26)
# elapsed time: 1.127303115 seconds
# (:epoch, 268, :trn, 8.451616f0, :length, 26)
# elapsed time: 0.987890396 seconds
# (:epoch, 269, :trn, 8.451615f0, :length, 26)
# elapsed time: 0.979646657 seconds
# (:epoch, 270, :trn, 8.451613f0, :length, 26)
# elapsed time: 1.122662977 seconds
# (:epoch, 271, :trn, 8.451615f0, :length, 26)
# elapsed time: 0.983592911 seconds
# (:epoch, 272, :trn, 8.451614f0, :length, 26)
# elapsed time: 0.981831547 seconds
# (:epoch, 273, :trn, 8.451613f0, :length, 26)
# elapsed time: 0.989378201 seconds
# (:epoch, 274, :trn, 8.451613f0, :length, 26)
# elapsed time: 1.125782238 seconds
# (:epoch, 275, :trn, 8.451612f0, :length, 26)
# elapsed time: 0.992847465 seconds
# (:epoch, 276, :trn, 8.451611f0, :length, 26)
# elapsed time: 0.981482296 seconds
# (:epoch, 277, :trn, 8.451611f0, :length, 26)
# elapsed time: 1.126414843 seconds
# (:epoch, 278, :trn, 8.451611f0, :length, 26)
# elapsed time: 0.984005942 seconds
# (:epoch, 279, :trn, 8.451609f0, :length, 26)
# elapsed time: 0.979967227 seconds
# (:epoch, 280, :trn, 8.451609f0, :length, 26)
# elapsed time: 0.983202954 seconds
# (:epoch, 281, :trn, 8.451609f0, :length, 26)
# elapsed time: 1.119632322 seconds
# (:epoch, 282, :trn, 8.451609f0, :length, 26)
# elapsed time: 0.978122433 seconds
# (:epoch, 283, :trn, 8.451609f0, :length, 26)
# elapsed time: 0.979957149 seconds
# (:epoch, 284, :trn, 8.451609f0, :length, 26)
# elapsed time: 1.123621462 seconds
# (:epoch, 285, :trn, 8.451607f0, :length, 26)
# elapsed time: 0.980194639 seconds
# (:epoch, 286, :trn, 8.451607f0, :length, 26)
# elapsed time: 0.976853185 seconds
# (:epoch, 287, :trn, 8.451606f0, :length, 26)
# elapsed time: 0.979501138 seconds
# (:epoch, 288, :trn, 8.451606f0, :length, 26)
# elapsed time: 1.110890173 seconds
# (:epoch, 289, :trn, 8.451606f0, :length, 26)
# elapsed time: 0.978247717 seconds
# (:epoch, 290, :trn, 8.451605f0, :length, 26)
# elapsed time: 0.973257444 seconds
# (:epoch, 291, :trn, 8.451605f0, :length, 26)
# elapsed time: 1.121603433 seconds
# (:epoch, 292, :trn, 8.451605f0, :length, 26)
# elapsed time: 0.97905802 seconds
# (:epoch, 293, :trn, 8.451603f0, :length, 26)
# elapsed time: 0.973293698 seconds
# (:epoch, 294, :trn, 8.451604f0, :length, 26)
# elapsed time: 0.980391786 seconds
# (:epoch, 295, :trn, 8.451604f0, :length, 26)
# elapsed time: 1.121374041 seconds
# (:epoch, 296, :trn, 8.451603f0, :length, 26)
# elapsed time: 0.978254881 seconds
# (:epoch, 297, :trn, 8.451602f0, :length, 26)
# elapsed time: 0.976145253 seconds
# (:epoch, 298, :trn, 8.451601f0, :length, 26)
# elapsed time: 1.11533568 seconds
# (:epoch, 299, :trn, 8.451601f0, :length, 26)
# elapsed time: 0.979319308 seconds
# (:epoch, 300, :trn, 8.451601f0, :length, 26)
# elapsed time: 0.976632573 seconds
# 304.296077 seconds (17.97 M allocations: 660.439 MiB, 26.12% gc time)
# (12500, 3)

# %%
gpu()
# Out:
# 0

# %%
samplein=reshape(samplein,12500,3)
samplein=Array{Float64,2}(samplein)
println(maximum(samplein[:,1]), minimum(samplein[:,1]))
println(maximum(samplein[:,2]), minimum(samplein[:,2]))
maximum(samplein[:,3]), minimum(samplein[:,3])
writedlm("samplein.xyz", samplein)
#dataset[1]
# Out:
# 0.92395001649856570.007438099943101406
# 0.58156800270080570.41107550263404846
